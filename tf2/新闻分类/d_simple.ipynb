# %% [markdown]
# # 简单分类器
# - 时间复杂度：低
# - 空间复杂度：低

# %%
from warnings import filterwarnings
filterwarnings('ignore')  # 不打印警告
from a_Data_preprocessing import load_xy
from b_metrics import metric, Timer
# %matplotlib inline

# %% [markdown]
# ## 数据加载、预处理

# %%
from sklearn.feature_extraction.text import CountVectorizer
X_train, X_test, y_train, y_test = load_xy()
vectorizer = CountVectorizer(token_pattern='\S+')
X_train = vectorizer.fit_transform([' '.join(x) for x in X_train])
X_test = vectorizer.transform([' '.join(x) for x in X_test])

# %% [markdown]
# ## 模型评估函数

# %%
def metrics(clf):
    t = Timer()  # 计时器
    y_pred = clf().fit(X_train, y_train).predict(X_test)
    metric(y_test, y_pred)

# %% [markdown]
# ### 贝叶斯

# %%
from sklearn.naive_bayes import MultinomialNB
metrics(MultinomialNB)
# Out:
#                 precision    recall  f1-score   support
#
#           car_       0.97      0.95      0.96       409
#     education_       0.86      0.85      0.85       410
# entertainment_       0.70      0.88      0.78       375
#       fashion_       0.80      0.76      0.78       394
#       finance_       0.84      0.79      0.81       402
#      military_       0.72      0.86      0.78       343
#      politics_       0.76      0.62      0.68       400
#       science_       0.80      0.75      0.78       372
#        sports_       0.99      0.97      0.98       393
#
#      micro avg       0.83      0.83      0.83      3498
#      macro avg       0.83      0.83      0.82      3498
#   weighted avg       0.83      0.83      0.83      3498
# 0.01分钟

# %% [markdown]
# ### 逻辑回归

# %%
from sklearn.linear_model import LogisticRegression
metrics(LogisticRegression)
# Out:
# D:\Software\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
#                 precision    recall  f1-score   support
#
#           car_       0.97      0.93      0.95       409
#     education_       0.89      0.90      0.90       410
# entertainment_       0.76      0.82      0.79       375
#       fashion_       0.76      0.81      0.78       394
#       finance_       0.88      0.83      0.86       402
#      military_       0.76      0.80      0.78       343
#      politics_       0.74      0.73      0.74       400
#       science_       0.84      0.78      0.81       372
#        sports_       0.99      0.96      0.97       393
#
#      micro avg       0.84      0.84      0.84      3498
#      macro avg       0.84      0.84      0.84      3498
#   weighted avg       0.85      0.84      0.84      3498
# 1.00分钟

# %% [markdown]
# ### 决策树

# %%
from sklearn.tree import DecisionTreeClassifier
metrics(DecisionTreeClassifier)
# Out:
#                 precision    recall  f1-score   support
#
#           car_       0.92      0.90      0.91       409
#     education_       0.77      0.78      0.77       410
# entertainment_       0.75      0.74      0.74       375
#       fashion_       0.65      0.71      0.68       394
#       finance_       0.80      0.74      0.77       402
#      military_       0.67      0.74      0.70       343
#      politics_       0.57      0.56      0.56       400
#       science_       0.78      0.74      0.76       372
#        sports_       0.95      0.93      0.94       393
#
#      micro avg       0.76      0.76      0.76      3498
#      macro avg       0.76      0.76      0.76      3498
#   weighted avg       0.76      0.76      0.76      3498
# 0.27分钟

# %% [markdown]
# ### 随机森林

# %%
from sklearn.ensemble import RandomForestClassifier
metrics(RandomForestClassifier)
# Out:
#                 precision    recall  f1-score   support
#
#           car_       0.92      0.95      0.93       409
#     education_       0.74      0.87      0.80       410
# entertainment_       0.73      0.79      0.76       375
#       fashion_       0.72      0.74      0.73       394
#       finance_       0.76      0.76      0.76       402
#      military_       0.76      0.80      0.78       343
#      politics_       0.66      0.53      0.59       400
#       science_       0.80      0.66      0.72       372
#        sports_       0.96      0.94      0.95       393
#
#      micro avg       0.78      0.78      0.78      3498
#      macro avg       0.78      0.78      0.78      3498
#   weighted avg       0.78      0.78      0.78      3498
# 0.16分钟
